# %%
import pandas as pd

# %%
# %%javascript
# var cell = Jupyter.notebook.get_cell(2).element[0];
#
# if (cell.style.position === 'fixed') {
#     cell.style.position = '';
#     cell.style.top = '';
#     cell.style.left = '';
#     cell.style.zIndex = '';
#     cell.style.background = '';
# } else {
#     cell.style.position = 'fixed';
#     cell.style.top = '0px';
#     cell.style.left = '433px';
#     cell.style.width = '1000px';
#     cell.style.zIndex = '999';
#     cell.style.background = 'white';
# }

# %%
df = pd.read_excel('flight_time.xlsx').set_index('departure_cities')
df

# %% [markdown]
# ## Instruction: Run the cells above. Then proceed below 👇

# %% [markdown]
# # 🗺️ Part 1 — Locate & Slicing

# %% [markdown]
# ### Q1 Using .iloc, retrieve the entire New York row.

# %%
answer = 
answer

# %% [markdown]
# ### Q2 Using .loc, find the flight time from New York → LA.

# %%
answer = 
answer

# %% [markdown]
# ### Q3 Using .iloc, retrieve the flight time from New York → LA.

# %%
answer = 
answer

# %% [markdown]
# ### Q4 Using .loc, retrieve the entire London row as a DataFrame.

# %%
answer = 
answer

# %% [markdown]
# ### Q5 Using .loc, find the intersection of the Paris and Tokyo rows with the LA and London columns.

# %%
answer = 
answer

# %% [markdown]
# ### Q6 Using .iloc, retrieve all rows and only the first and last columns.

# %%
answer = 
answer

# %% [markdown]
# ### Q7 Using .iloc, retrieve the first 2 rows.

# %%
answer = 
answer

# %% [markdown]
# ### Q8 Using .iloc, retrieve the last 3 columns.

# %%
answer = 
answer

# %% [markdown]
# ### Q9 Using .loc, retrieve rows from LA through Paris, inclusive.

# %%
answer = 
answer

# %% [markdown]
# ### Q10 Using .iloc, retrieve the first 3 rows and last 4 columns.

# %%
answer = 
answer

# %% [markdown]
# ### Q11 Using .iloc, retrieve the table excluding the first row.

# %%
answer = 
answer

# %% [markdown]
# ### Q12 Using .iloc, retrieve the table excluding the last row and last column.

# %%
answer = 
answer

# %% [markdown]
# # 🛂✅ Part 2 — Filtering & Assignment

# %% [markdown]
# ### Q13 Using .loc, retrieve all columns except Tokyo.

# %%
answer = 
answer

# %% [markdown]
# ### Q14 Using .loc, retrieve the subtable containing rows London through Tokyo and columns London through Dubai.

# %%
answer = 
answer

# %% [markdown]
# ### Q15 From your home city, the flight to Paris is 10.8 hours. How long would it take you to fly to Dubai?

# %%
answer = 
answer

# %% [markdown]
# ### Q16 Using .loc, locate the rows where the flight time *to Paris* is more than 10 hours.

# %%
answer = 
answer

# %% [markdown]
# ### Q17 You have a long vacation. Find all departure airports where the flight to Paris takes more than 10 hours. Return them in a list.

# %%
answer = 
answer

# %% [markdown]
# ### Q18 You'd like to visit Sydney, but only if the flight is between 10 and 20 hours. Which departure airport(s) meet that requirement? Return the row(s).

# %%
answer = 
answer

# %% [markdown]
# ### Q19 You know your flight to Seoul takes 12.0 hours. How long would the flight to Paris take from the same city?

# %%
answer = 
answer

# %% [markdown]
# ### Q20 Visiting new places: You will visit London and Paris. The flight time from your home city to both cities is under 10 hours. Where are you?
# Hint: departure city is not London or Paris

# %%
answer = 
answer

# %% [markdown]
# ### Q21 Use .iloc to retrieve the first 3 rows, then .loc to retrieve Paris through Sydney columns.

# %%
answer = 
answer

# %% [markdown]
# ### Q22 Using .loc, change the New York → LA flight time to 6.1.

# %% [markdown]
# ### Q23 Using a Boolean condition with .loc, change all flights to Dubai shorter than 8 hr to 8.

# %% [markdown]
# ### Q24 Bad weather: Due to a storm system, all intercontinental flights into East & Southeast Asia are canceled. Locate those flights routes and reassign them as "canceled".
# Hint: flight origin is not Tokyo. Flight destinations include Tokyo, Seoul, and Singapore.
